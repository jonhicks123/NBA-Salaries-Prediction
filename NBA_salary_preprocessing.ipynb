# %%
import pandas as pd
import datetime as dt
import os

# %%
nba_path = "Data/Season_Stats.csv"
df = pd.read_csv(nba_path, index_col=[0])
df
# Out:
#               Player Pos    Salary           Country  Age   Tm   G  GS    MP  \
# 1       Aaron Brooks  PG   2116955               USA   32  IND  65   0   894
# 2       Aaron Gordon  SF   5504420               USA   21  ORL  80  72  2298
# 3     Aaron Harrison  SG     83129               USA   22  CHO   5   0    17
# 4         Al Horford   C  27734405  Dominican Rep...   30  BOS  68  68  2193
# 5       Al Jefferson   C   9769821               USA   32  IND  66   1   931
# ..               ...  ..       ...               ...  ...  ...  ..  ..   ...
# 377  Wilson Chandler  SF  12016854               USA   29  DEN  71  33  2197
# 378     Yogi Ferrell  PG   1312611               USA   23  TOT  46  29  1197
# 379      Zach LaVine  SG   3202217               USA   21  MIN  47  47  1749
# 380    Zach Randolph  PF  12307692               USA   35  MEM  73   5  1786
# 381    Zaza Pachulia   C   3477600           Georgia   32  GSW  70  70  1268
#
# ...

# %%
df = df.drop(columns=['blanl', 'blank2'])

# %%
df.isnull().any()
# Out:
# Player     False
# Pos        False
# Salary     False
# Country    False
# Age        False
# Tm         False
# G          False
# GS         False
# MP         False
# PER        False
# TS%        False
# 3PAr       False
# FTr        False
# ORB%       False
# DRB%       False
# TRB%       False
# AST%       False
# STL%       False
# BLK%       False
# TOV%       False
# USG%       False
# OWS        False
# DWS        False
# WS         False
# WS/48      False
# OBPM       False
# DBPM       False
# BPM        False
# VORP       False
# FG         False
# FGA        False
# FG%        False
# 3P         False
# 3PA        False
# 3P%         True
# 2P         False
# 2PA        False
# 2P%        False
# eFG%       False
# FT         False
# FTA        False
# FT%         True
# ORB        False
# DRB        False
# TRB        False
# AST        False
# STL        False
# BLK        False
# TOV        False
# PF         False
# PTS        False
# dtype: bool

# %%
df = df.dropna()
df
# Out:
#               Player Pos    Salary           Country  Age   Tm   G  GS    MP  \
# 1       Aaron Brooks  PG   2116955               USA   32  IND  65   0   894
# 2       Aaron Gordon  SF   5504420               USA   21  ORL  80  72  2298
# 3     Aaron Harrison  SG     83129               USA   22  CHO   5   0    17
# 4         Al Horford   C  27734405  Dominican Rep...   30  BOS  68  68  2193
# 5       Al Jefferson   C   9769821               USA   32  IND  66   1   931
# ..               ...  ..       ...               ...  ...  ...  ..  ..   ...
# 377  Wilson Chandler  SF  12016854               USA   29  DEN  71  33  2197
# 378     Yogi Ferrell  PG   1312611               USA   23  TOT  46  29  1197
# 379      Zach LaVine  SG   3202217               USA   21  MIN  47  47  1749
# 380    Zach Randolph  PF  12307692               USA   35  MEM  73   5  1786
# 381    Zaza Pachulia   C   3477600           Georgia   32  GSW  70  70  1268
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["Salary"], df["PTS"])

# %%
df.to_csv('Data/Clean_2017_NBA_Stats.csv')
